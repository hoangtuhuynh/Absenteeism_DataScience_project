# %%
from absenteeism_module import *

# %%
data  = pd.read_csv('Absenteeism_new_data.csv')
data
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %%
model = absenteeism_model('model', 'scaler') # a file named model and scaler which was created from the machine learning part

# The instance of the 'absenteeism_model' class is now in the variable called 'model'

model.load_and_clean_data('Absenteeism_new_data.csv') # this function will preprocess the entire data set we provide

# %%
# its role is to feed the cleaned data into the model, and deliver the output we discussed
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
model.predicted_outputs().to_csv('Absenteesim_predictions.csv', index=False)

# %%
predicted_data = pd.read_csv('Absenteesim_predictions.csv')
predicted_data.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0       0.0         0         1            6
# 1         1       0.0         0         0            6
# 2         0       0.0         0         1            6
# 3         0       0.0         0         1            6
# 4         1       0.0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.127203           0
# 1     0.864029           1
# 2     0.265096           0
# 3     0.202894           0
# 4     0.719413           1

# %%
import matplotlib.pyplot as plt
x1 = predicted_data['Age']
y = predicted_data['Probability']
plt.scatter(x1,y *100,color='C0')
plt.xlabel('Age', fontsize = 20)
plt.ylabel('Probability', fontsize = 20)
plt.show()
